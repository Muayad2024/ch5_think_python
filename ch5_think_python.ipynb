# %%
from time import time 
now = time()
minute = now // 60
hours = minute // 60
days = hours // 24
years = days // 365
print("Current minute:", minute)
print("Current hour:", hours)
print("Current day:", days)
print("Current year:", years)
# Out:
# Current minute: 29623251.0
# Current hour: 493720.0
# Current day: 20571.0
# Current year: 56.0

# %%
def is_triangle(x, y, z):
    if x + y > z or x + z > y or y + z > x:
        print ("Yes")
    elif x + y == z or x + z == y or y + z == x:
        print ("Degenerate")
    else:
        print('no')

# %%
def recurse(n, s):
    if n == 0:
        print(s)
    else:
        recurse(n-1, n+s)
recurse(3, 0)
# Out:
# 6

# %%
from jupyturtle import forward, left, right, back, make_turtle
def draw(length):
    angle = 50
    factor = 0.6
    if length > 5:
        forward(length) 
        left(angle)
        draw(factor * length) 
        right(2 * angle)
        draw(factor * length) 
        left(angle)
        back(length)
make_turtle(width=500, height=400, delay=0) 
draw(50)
# Out:
# <svg width="500" height="400" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 250,200 300,200 319.3,177 316.2,159.3 306.8,153.9 300.7,156.1 306.8,153.9 305.7,147.5 306.8,153.9 316.2,159.3 323.1,151 322,144.6 323.1,151 329.6,151 323.1,151 316.2,159.3 319.3,177 337.3,177 344.2,168.7 343.1,162.4 344.2,168.7 350.7,168.7 344.2,168.7 337.3,177 344.2,185.3 350.7,185.3 344.2,185.3 343.1,191.7 344.2,185.3 337.3,177 319.3,177 300,200 319.3,223 337.3,223 344.2,214.7 343.1,208.3 344.2,214.7 350.7,214.7 344.2,214.7 337.3,223 344.2,231.3 350.7,231.3 344.2,231.3 343.1,237.6 344.2,231.3 337.3,223 319.3,223 316.2,240.7 323.1,249 329.6,249 323.1,249 322,255.4 323.1,249 316.2,240.7 306.8,246.1 305.7,252.5 306.8,246.1 300.7,243.9 306.8,246.1 316.2,240.7 319.3,223 300,200 250,200" />'
#
# <g transform="rotate(-90.0,250.0,200.0) translate(250.0, 200.0)">
# ...

# %%
import math
math.sqrt(42 / math.pi)
# Out:
# 3.656366395715726
